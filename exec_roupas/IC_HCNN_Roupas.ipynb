# %% [markdown]
# ## Depedências

# %%
import kagglehub
import pickle
import os
import keras
import numpy as np
import pandas as pd
import pickle
from PIL import Image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Concatenate, Add, Softmax, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Input, BatchNormalization
from tensorflow.keras.initializers import he_normal
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import LearningRateScheduler, TensorBoard, CSVLogger
from tensorflow.keras.utils import get_file
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import set_random_seed
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from scipy import stats
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# Relations for Fashion MNIST
c2_to_c1 = {
    0:0, 1:0, 2:0,
    3:1, 4:1, 5:1,
    6:2, 7:2, 8:2,
    9:3, 10:3, 11:3,
}
fine_to_c2 = {
    0:0, 1:0, 2:0,
    3:1, 4:1, 5:1,
    6:2, 7:2, 8:2,
    9:3,
    10:4, 11:4, 12:4,
    13:5, 14:5, 15:5,
    16:6, 17:6, 18:6,
    19:7,
    20:8, 21:8, 22:8,
    23:9, 24:9, 25:9,
    26:10, 27:10, 28:10,
    29:11,
}

unique_fine = [*range(0, 30, 1)]
unique_c2 = np.vectorize(fine_to_c2.get)(unique_fine)
unique_c1 = np.vectorize(c2_to_c1.get)(unique_c2)

relations = []
for i in range(30):
  relations.append([unique_c1[i],unique_c2[i]+2,unique_fine[i]+8])

# Computes hierarchical metrics
def hierarchical_metrics(true,pred):
  true_labels = []
  true_fine = true[2].argmax(axis=1)+8
  true_c2 = true[1].argmax(axis=1)+2
  true_c1 = true[0].argmax(axis=1)
  for i in range(len(true_fine)):
    true_labels.append([true_c1[i],true_c2[i],true_fine[i]])
  pred_labels = []
  pred_c1 = pred[0].argmax(axis = 1)
  pred_c2 = pred[1].argmax(axis = 1)+2
  pred_fine = pred[2].argmax(axis = 1)+8
  for i in range(len(pred_c1)):
    pred_labels.append([pred_c1[i],pred_c2[i],pred_fine[i]])
  preci = precision(true_labels,pred_labels)
  reca = recall(true_labels,pred_labels)
  f_1 = f1(true_labels,pred_labels)

  consistent_examples = 1
  correct_pred = 0
  test_set_size = len(true_labels)
  for i in range(test_set_size):
    if [pred_c1[i],pred_c2[i],pred_fine[i]] in relations:
        consistent_examples = consistent_examples + 1
    if [pred_c1[i],pred_c2[i],pred_fine[i]] == true_labels[i]:
        correct_pred = correct_pred +1
  h_accuracy = correct_pred/test_set_size
  h_consistency = (consistent_examples-1)/test_set_size

  return h_accuracy,h_consistency,f_1

# Hierarchical metrics, proposed by Kiritchenko et al (2005)
# Implementation
# https://gitlab.com/dacs-hpi/hiclass/-/blob/main/hiclass/metrics.py


def precision(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute precision score for hierarchical classification.

    hP = sum(|S intersection T|) / sum(|S|),
    where S is the set consisting of the most specific class(es) predicted for a test example and all respective ancestors
    and T is the set consisting of the true most specific class(es) for a test example and all respective ancestors.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    precision : float
        What proportion of positive identifications was actually correct?
    """
    assert len(y_true) == len(y_pred)
    sum_intersection = 0
    sum_prediction_and_ancestors = 0
    for ground_truth, prediction in zip(y_true, y_pred):
        sum_intersection = sum_intersection + len(
            set(ground_truth).intersection(set(prediction))
        )
        sum_prediction_and_ancestors = sum_prediction_and_ancestors + len(
            set(prediction)
        )
    precision = sum_intersection / sum_prediction_and_ancestors
    return precision


def recall(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute recall score for hierarchical classification.

    hR = sum(|S intersection T|) / sum(|T|),
    where S is the set consisting of the most specific class(es) predicted for a test example and all respective ancestors
    and T is the set consisting of the true most specific class(es) for a test example and all respective ancestors.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    recall : float
        What proportion of actual positives was identified correctly?
    """
    assert len(y_true) == len(y_pred)
    sum_intersection = 0
    sum_prediction_and_ancestors = 0
    for ground_truth, prediction in zip(y_true, y_pred):
        sum_intersection = sum_intersection + len(
            set(ground_truth).intersection(set(prediction))
        )
        sum_prediction_and_ancestors = sum_prediction_and_ancestors + len(
            set(ground_truth)
        )
    recall = sum_intersection / sum_prediction_and_ancestors
    return recall


def f1(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute f1 score for hierarchical classification.

    hF = 2 * hP * hR / (hP + hR),
    where hP is the hierarchical precision and hR is the hierarchical recall.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    f1 : float
        Weighted average of the precision and recall
    """
    assert len(y_true) == len(y_pred)
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    f1 = 2 * prec * rec / (prec + rec)
    return f1

# %% [markdown]
# ## Configurações Gerais

# %%
# Baixa última versão do dataset
path = kagglehub.dataset_download("paramaggarwal/fashion-product-images-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/fashion-product-images-dataset

# %%
# Carrega o arquivo de metadados
styles_csv_path = '/kaggle/input/fashion-product-images-dataset/fashion-dataset/styles.csv'
#styles_csv_path = '/root/.cache/kagglehub/datasets/paramaggarwal/fashion-product-images-dataset/versions/1/fashion-dataset/styles.csv'
styles_df = pd.read_csv(styles_csv_path, on_bad_lines='skip')

#----------------------------Primeira filtragem pelo masterCategory----------------------------
# Conta as ocorrências da categoria master
master_category_counts = styles_df['masterCategory'].value_counts()

# Pega as 4 maiores
top_4_master_categories = master_category_counts.nlargest(4).index.tolist()

# Filtra pelas 4 maiores
filtered_styles_df = styles_df[styles_df['masterCategory'].isin(top_4_master_categories)]
#----------------------------Primeira filtragem----------------------------

#----------------------------Segunda filtragem pelo subCategory----------------------------
top_3_subcategories_per_master = {}
filtered_styles_df_by_top_subcategories = pd.DataFrame()

for master_cat in top_4_master_categories:
    # Filtra o dataframe por categoria principal
    df_master_cat = styles_df[styles_df['masterCategory'] == master_cat]

    # Obtenha as 3 subcategorias mais frequentes para esta categoria principal
    top_sub_categories = df_master_cat['subCategory'].value_counts().nlargest(3).index.tolist()
    top_3_subcategories_per_master[master_cat] = top_sub_categories

    # Filtra pelas 3 subcategorias
    df_filtered_sub = df_master_cat[df_master_cat['subCategory'].isin(top_sub_categories)]

    filtered_styles_df_by_top_subcategories = pd.concat([filtered_styles_df_by_top_subcategories, df_filtered_sub])
#----------------------------Segunda filtragem pelo subCategory----------------------------

#----------------------------Terceira filtragem----------------------------
top_3_article_types_per_subcategory = {}
dataset = pd.DataFrame()

# Iterate through the subcategories that are already filtered
for sub_cat in filtered_styles_df_by_top_subcategories['subCategory'].unique():
    df_sub_cat = filtered_styles_df_by_top_subcategories[filtered_styles_df_by_top_subcategories['subCategory'] == sub_cat]

    top_article_types = df_sub_cat['articleType'].value_counts().nlargest(3).index.tolist()
    top_3_article_types_per_subcategory[sub_cat] = top_article_types

    df_filtered_article = df_sub_cat[df_sub_cat['articleType'].isin(top_article_types)]

    dataset = pd.concat([dataset, df_filtered_article])
#----------------------------Terceira filtragem----------------------------
print(top_3_article_types_per_subcategory)
# Out:
# {'Topwear': ['Tshirts', 'Shirts', 'Kurtas'], 'Bottomwear': ['Jeans', 'Shorts', 'Trousers'], 'Innerwear': ['Briefs', 'Bra', 'Innerwear Vests'], 'Watches': ['Watches'], 'Bags': ['Handbags', 'Backpacks', 'Clutches'], 'Jewellery': ['Earrings', 'Pendant', 'Necklace and Chains'], 'Shoes': ['Casual Shoes', 'Sports Shoes', 'Heels'], 'Flip Flops': ['Flip Flops'], 'Sandal': ['Sandals', 'Sports Sandals', 'Flip Flops'], 'Fragrance': ['Perfume and Body Mist', 'Deodorant', 'Fragrance Gift Set'], 'Lips': ['Lipstick', 'Lip Gloss', 'Lip Liner'], 'Nails': ['Nail Polish']}

# %%
## Dimensões da imagem
height, width = 32, 32

channel = 3
if K.image_data_format() == 'channels_first':
    input_shape = (channel, height, width)
else:
    input_shape = (height, width, channel)

# %%
train_size = int(dataset.shape[0] * 0.70)
test_size = int(np.floor(dataset.shape[0] * 0.15))
val_size = int(np.ceil(dataset.shape[0] * 0.15))

train_df, temp_df = train_test_split(
    dataset,
    test_size=(val_size + test_size) / len(dataset),
    random_state=42,
    stratify=dataset['articleType']
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=test_size / (val_size + test_size),
    random_state=42,
    stratify=temp_df['articleType']
)


# Quantidade de classes no primeiro nível hierárquico camada
coarse1_classes = 4

# Quantidade de classes no segundo nível hierárquico camada
coarse2_classes = 12

# Quantidade de classes no último nível hierárquico (folhas da árvore)
num_classes  = 30

batch_size   = 128
epochs       = 10

# %%
def scheduler(epoch):
  learning_rate_init = 0.001
  if epoch > 55:
    learning_rate_init = 0.0002
  if epoch > 70:
    learning_rate_init = 0.00005
  return learning_rate_init

# %%
class LossWeightsModifier(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    # customize your behavior
  def on_epoch_end(self, epoch, logs={}):
    if epoch == 15:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.2)
      K.set_value(self.gamma, 0.7)
    if epoch == 25:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.2)
      K.set_value(self.gamma, 0.7)
    if epoch == 35:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.2)
      K.set_value(self.gamma, 0.7)

# %%
class_names =[
  "Tshirts",
  "Shirts",
  "Kurtas",
  "Jeans",
  "Shorts",
  "Trousers",
  "Briefs",
  "Bra",
  "Innerwear Vests",
  "Watches",
  "Handbags",
  "Backpacks",
  "Clutches",
  "Earrings",
  "Pendant",
  "Necklace and Chains",
  "Casual Shoes",
  "Sports Shoes",
  "Heels",
  "Flip Flops",
  "Sandals",
  "Sports Sandals",
  "Flip Flops",
  "Perfume and Body Mist",
  "Deodorant",
  "Fragrance Gift Set",
  "Lipstick",
  "Lip Gloss",
  "Lip Liner",
  "Nail Polish",
]

class_names_c1 = ['Apparel', 'Accessories','Footwear','Personal Care']
class_names_c2 = ['Topwear', 'Bottomwear', 'Innerwear', 'Watches', 'Bags', 'Jewellery', 'Shoes', 'Flip Flops', 'Sandal', 'Fragrance', 'Lips', 'Nails']

class_names_index = {class_name: index for index, class_name in enumerate(class_names)}

def print_mappings(mapping, source, dest):
    for k,v in mapping.items():
        print(source[k], "->", dest[v])

print_mappings(c2_to_c1, class_names_c2, class_names_c1)
print("-"*10)
print_mappings(fine_to_c2, class_names, class_names_c2)
# Out:
# Topwear -> Apparel
# Bottomwear -> Apparel
# Innerwear -> Apparel
# Watches -> Accessories
# Bags -> Accessories
# Jewellery -> Accessories
# Shoes -> Footwear
# Flip Flops -> Footwear
# Sandal -> Footwear
# Fragrance -> Personal Care
# Lips -> Personal Care
# Nails -> Personal Care
# ----------
# Tshirts -> Topwear
# Shirts -> Topwear
# Kurtas -> Topwear
# Jeans -> Bottomwear
# Shorts -> Bottomwear
# Trousers -> Bottomwear
# Briefs -> Innerwear
# Bra -> Innerwear
# Innerwear Vests -> Innerwear
# Watches -> Watches
# Handbags -> Bags
# Backpacks -> Bags
# Clutches -> Bags
# Earrings -> Jewellery
# Pendant -> Jewellery
# Necklace and Chains -> Jewellery
# Casual Shoes -> Shoes
# Sports Shoes -> Shoes
# Heels -> Shoes
# Flip Flops -> Flip Flops
# Sandals -> Sandal
# Sports Sandals -> Sandal
# Flip Flops -> Sandal
# Perfume and Body Mist -> Fragrance
# Deodorant -> Fragrance
# Fragrance Gift Set -> Fragrance
# Lipstick -> Lips
# Lip Gloss -> Lips
# Lip Liner -> Lips
# Nail Polish -> Nails

# %%
#----------Pega os pesos do modelo VGG16 pré-treinado--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file(
    'vgg16_weights_tf_dim_ordering_tf_kernels.h5',
    WEIGHTS_PATH,
    cache_subdir='models',
)

# # Carregando os dados caso não tenha salvo anteriormente
# train_path = '/kaggle/input/fashion-product-images-dataset/fashion-dataset/images/'

# Inicializa listas de dados
x_train, y_train = [], []
x_test, y_test = [], []
x_val, y_val = [], []


# Carrega os dados salvos
with open('fashion_data.pkl', 'rb') as f:
    data = pickle.load(f)
    x_train = data['x_train']
    y_train = data['y_train']
    x_test = data['x_test']
    y_test = data['y_test']
    x_val = data['x_val']
    y_val = data['y_val']

# One Hot Encondig para as labels fine
train_labels_fine = to_categorical(y_train)
test_labels_fine = to_categorical(y_test)
val_labels_fine = to_categorical(y_val)

# One Hot Encoding para as labels da segunda camada grossa
train_labels_c2_index = [fine_to_c2[i] for i in y_train]
train_labels_c2 = to_categorical(train_labels_c2_index)

test_labels_c2_index = [fine_to_c2[i] for i in y_test]
test_labels_c2 = to_categorical(test_labels_c2_index)

val_labels_c2_index = [fine_to_c2[i] for i in y_val]
val_labels_c2 = to_categorical(val_labels_c2_index)

# One Hot Enconding para as labels da primeira camada grossa
train_labels_c1_index = [c2_to_c1[i] for i in train_labels_c2_index]
train_labels_c1 = to_categorical(train_labels_c1_index)

test_labels_c1_index = [c2_to_c1[i] for i in test_labels_c2_index]
test_labels_c1 = to_categorical(test_labels_c1_index)

val_labels_c1_index = [c2_to_c1[i] for i in val_labels_c2_index]
val_labels_c1 = to_categorical(val_labels_c1_index)

# Finalmente criando as variáveis labels para treino, teste e validação
y_train = train_labels_fine
y_test = test_labels_fine
y_val = val_labels_fine

y_c1_train = train_labels_c1
y_c1_test = test_labels_c1
y_c1_val = val_labels_c1

y_c2_train = train_labels_c2
y_c2_test = test_labels_c2
y_c2_val = val_labels_c2

# Coloca o Channel por último
x_train = x_train.transpose(0, 2, 3, 1)
x_test = x_test.transpose(0, 2, 3, 1)
x_val = x_val.transpose(0, 2, 3, 1)

print("x_train shape: ", x_train.shape)
print("x_test shape: ", x_test.shape)
print("x_val shape: ", x_val.shape)

print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)
print("y_val shape: ", y_val.shape)

print("y_c1_train shape: ", y_c1_train.shape)
print("y_c1_test shape: ", y_c1_test.shape)
print("y_c1_val shape: ", y_c1_val.shape)

print("y_c2_train shape: ", y_c2_train.shape)
print("y_c2_test shape: ", y_c2_test.shape)
print("y_c2_val shape: ", y_c2_val.shape)

# Transforma o id das imagens para indices
# id_to_index = {image_id: index for index, image_id in enumerate(dataset['id'])}

# # Loop para carregar imagens com shape fixo (3, 32, 32)
# for image_id in dataset['id']:
#     image_filename = str(image_id) + '.jpg'
#     image_path = os.path.join(train_path, image_filename)

#     if os.path.exists(image_path):
#         dataset_index = id_to_index[image_id]

#         img = Image.open(image_path).convert("RGB")  # Garante 3 canais
#         img = img.resize((width, height))
#         img_array = np.array(img)

#         if image_id in train_df['id'].values:
#             x_train.append(img_array)
#             y_train.append(class_names_index[dataset.iloc[dataset_index]['articleType']])

#         elif image_id in test_df['id'].values:
#             x_test.append(img_array)
#             y_test.append(class_names_index[dataset.iloc[dataset_index]['articleType']])

#         elif image_id in val_df['id'].values:
#             x_val.append(img_array)
#             y_val.append(class_names_index[dataset.iloc[dataset_index]['articleType']])


# x_train = np.array(x_train).transpose(0, 3, 1, 2).astype("float32")
# x_test = np.array(x_test).transpose(0, 3, 1, 2).astype("float32")
# x_val = np.array(x_val).transpose(0, 3, 1, 2).astype("float32")

# x_train = (x_train - np.mean(x_train)) / np.std(x_train)
# x_test = (x_test - np.mean(x_test)) / np.std(x_test)
# x_val = (x_val - np.mean(x_val)) / np.std(x_val)

# y_train = np.array(y_train)
# y_test = np.array(y_test)
# y_val = np.array(y_val)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# x_train shape:  (21955, 32, 32, 3)
# x_test shape:  (4705, 32, 32, 3)
# x_val shape:  (4704, 32, 32, 3)
# y_train shape:  (21955, 30)
# y_test shape:  (4705, 30)
# y_val shape:  (4704, 30)
# y_c1_train shape:  (21955, 4)
# y_c1_test shape:  (4705, 4)
# y_c1_val shape:  (4704, 4)
# y_c2_train shape:  (21955, 12)
# y_c2_test shape:  (4705, 12)
# y_c2_val shape:  (4704, 12)

# %% [markdown]
# # H-CNN

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.1, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.2, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.7, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.1, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.2, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.7, dtype="float32", name="gamma") # A3 in paper
img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch_flatt = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(512, activation='relu', name='c1_fc_cifar10_1')(c_1_bch_flatt)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(512, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(coarse1_classes, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch_flatt = Flatten(name='c2_flatten')(x)
c_2_bch_concat = Concatenate()([c_1_bch_flatt,c_2_bch_flatt]) # Conectivity Pattern
c_2_bch = Dense(1024, activation='relu', name='c2_fc_cifar100_1')(c_2_bch_concat)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(1024, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(coarse2_classes, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x_flatt = Flatten(name='flatten')(x)
x = Concatenate()([c_2_bch_concat,x_flatt]) # Conectivity Pattern
x = Dense(4096, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='hcnn_base_c')
model.load_weights(weights_path, by_name=True)
#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss=['categorical_crossentropy','categorical_crossentropy','categorical_crossentropy'],
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy','accuracy','accuracy'])
model.summary()
# Out:
# Model: "hcnn_base_c"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 32, 32, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 32, 32,    │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 32, 32,    │     36,928 │ batch_normalizat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 16, 16,    │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ block2_conv1[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 16, 16,    │    147,584 │ batch_normalizat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ block2_conv2[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 8, 8, 256) │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 4, 4, 512) │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 2, 2, 512) │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_flatten          │ (None, 8192)      │          0 │ block2_pool[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_flatten          │ (None, 4096)      │          0 │ block3_pool[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12288)     │          0 │ c1_flatten[0][0], │
# │ (Concatenate)       │                   │            │ c2_flatten[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 14336)     │          0 │ concatenate[0][0… │
# │ (Concatenate)       │                   │            │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fc_cifar10_1     │ (None, 512)       │  4,194,816 │ c1_flatten[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fc_cifar100_1    │ (None, 1024)      │ 12,583,936 │ concatenate[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc_cifar10_1        │ (None, 4096)      │ 58,724,352 │ concatenate_1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ c1_fc_cifar10_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ c2_fc_cifar100_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4096)      │     16,384 │ fc_cifar10_1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1024)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4096)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fc2 (Dense)      │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fc2 (Dense)      │ (None, 1024)      │  1,049,600 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2 (Dense)         │ (None, 4096)      │ 16,781,312 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ c1_fc2[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ c2_fc2[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4096)      │     16,384 │ fc2[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 1024)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4096)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_predictions_cif… │ (None, 4)         │      2,052 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_predictions_cif… │ (None, 12)        │     12,300 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions_cifar10 │ (None, 30)        │    122,910 │ dropout_5[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 108,510,574 (413.93 MB)
#  Trainable params: 108,479,598 (413.82 MB)
#  Non-trainable params: 30,976 (121.00 KB)

# %%
import zipfile
import os
from google.colab import files

# Callbacks
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_hcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_h_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_h_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_h_cnn_c,cons_h_cnn_c,f1_h_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("2h_cnn_base1.keras")

# Save results to file
with open('2results_h_cnn_base.txt', 'w') as f:  # New file for B-CNN
  f.write("--- h-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_h_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_h_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_h_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_h_cnn_c}\n")
  f.write(f"Consistency: {cons_h_cnn_c}\n")
  f.write(f"F1: {f1_h_cnn_c}\n")
  f.write(f"Parameters: {parameters_h_cnn_c:,}\n")

# Define file names
model_file = "2h_cnn_base1.keras"
results_file = "2results_h_cnn_base1.txt"
zip_file = "2h_cnn_base_results1.zip"

# Create a zip archive with both files
with zipfile.ZipFile(zip_file, 'w') as zipf:
    zipf.write(model_file)
    zipf.write(results_file)

# Download the zip file to local machine
files.download(zip_file)

# Results
print("--- H-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_h_cnn_c[4])
print("Accuracy level 2:",score_h_cnn_c[5])
print("Accuracy level 3:",score_h_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Accuracy:",acc_h_cnn_c)
print("Consistency:",cons_h_cnn_c)
print("f1:",f1_h_cnn_c)
print("Parameters:","{:,}".format(parameters_h_cnn_c))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-88c7e012d384> in <cell line: 0>()
#      12   cbks = [change_lr]
#      13
# ---> 14 history_hcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
#      15           batch_size=batch_size,
#      16           epochs=epochs,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     887       # This is the first call of __call__, so we have to initialize.
#     888       initializers = []
# --> 889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#     601
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337   if is_autograph_artifact(f):
#     338     logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339     return _call_unconverted(f, args, kwargs, options)
#     340
#     341   # If this is a partial, unwrap it and redo all the checks.
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#     644
#     645   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in multi_step_on_iterator(iterator)
#     130             if self.steps_per_execution == 1:
#     131                 return tf.experimental.Optional.from_value(
# --> 132                     one_step_on_data(iterator.get_next())
#     133                 )
#     134
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     887       # This is the first call of __call__, so we have to initialize.
#     888       initializers = []
# --> 889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#     601
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337   if is_autograph_artifact(f):
#     338     logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339     return _call_unconverted(f, args, kwargs, options)
#     340
#     341   # If this is a partial, unwrap it and redo all the checks.
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#     644
#     645   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in one_step_on_data(data)
#     111         def one_step_on_data(data):
#     112             """Runs a single training step on a batch of data."""
# --> 113             outputs = self.distribute_strategy.run(step_function, args=(data,))
#     114             outputs = reduce_per_replica(
#     115                 outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1671       fn = autograph.tf_convert(
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1674
#    1675   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    3261       kwargs = {}
#    3262     with self._container_strategy().scope():
# -> 3263       return self._call_for_each_replica(fn, args, kwargs)
#    3264
#    3265   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    4059   def _call_for_each_replica(self, fn, args, kwargs):
#    4060     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061       return fn(*args, **kwargs)
#    4062
#    4063   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#     644
#     645   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in train_step(self, data)
#      55         with tf.GradientTape() as tape:
#      56             if self._call_has_training_arg:
# ---> 57                 y_pred = self(x, training=True)
#      58             else:
#      59                 y_pred = self(x)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(self, inputs, training, mask)
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/function.py in _run_through_graph(self, inputs, operation_fn, call_fn)
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(*args, **kwargs)
#     635         ):
#     636             kwargs["training"] = training
# --> 637         return operation(*args, **kwargs)
#     638
#     639     return call
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py in call(self, inputs, training, mask)
#     249         inputs = ops.cast(inputs, compute_dtype)
#     250
# --> 251         moving_mean = ops.cast(self.moving_mean, inputs.dtype)
#     252         moving_variance = ops.cast(self.moving_variance, inputs.dtype)
#     253
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/core.py in cast(x, dtype)
#     801     if any_symbolic_tensors((x,)):
#     802         return Cast(dtype=dtype)(x)
# --> 803     return backend.core.cast(x, dtype)
#     804
#     805
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/core.py in cast(x, dtype)
#     199         return x
#     200     else:
# --> 201         return tf.cast(x, dtype=dtype)
#     202
#     203
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#    1010       # allows some conversions that cast() can't do, e.g. casting numbers to
#    1011       # strings.
# -> 1012       x = ops.convert_to_tensor(x, name="x")
#    1013       if x.dtype.is_complex and base_type.is_floating:
#    1014         logging.warn(
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     730   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     731   preferred_dtype = preferred_dtype or dtype_hint
# --> 732   return tensor_conversion_registry.convert(
#     733       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     734   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207   overload = getattr(value, "__tf_tensor__", None)
#     208   if overload is not None:
# --> 209     return overload(dtype, name)  #  pylint: disable=not-callable
#     210
#     211   for base_type, conversion_func in get(type(value)):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/core.py in __tf_tensor__(self, dtype, name)
#      77     # Overload native accessor.
#      78     def __tf_tensor__(self, dtype=None, name=None):
# ---> 79         return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#      80
#      81     # Methods below are for SavedModel support
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169   """Converts the given `value` to a `Tensor`."""
#     170   # preferred_dtype = preferred_dtype or dtype_hint
# --> 171   return tensor_conversion_registry.convert(
#     172       value, dtype, name, preferred_dtype=dtype_hint
#     173   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     232
#     233     if ret is None:
# --> 234       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     235
#     236     if ret is NotImplemented:
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2373
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)  # pylint: disable=protected-access
#    2376
#    2377
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _dense_var_to_tensor(***failed resolving arguments***)
#    1619       return self.read_value().op.inputs[0]
#    1620     else:
# -> 1621       return self.value()
#    1622
#    1623   def __iadd__(self, unused_other):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py in value(self)
#     654       return self._cached_value
#     655     with ops.colocate_with(None, ignore_existing=True):
# --> 656       return self._read_variable_op()
#     657
#     658   def _as_graph_element(self):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _read_variable_op(self, no_copy)
#     839           result = read_and_set_handle(no_copy)
#     840     else:
# --> 841       result = read_and_set_handle(no_copy)
#     842
#     843     if not context.executing_eagerly():
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_and_set_handle(no_copy)
#     829       if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830         gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831       result = gen_resource_variable_ops.read_variable_op(
#     832           self.handle, self._dtype)
#     833       _maybe_set_handle_data(self._dtype, self.handle, result)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_resource_variable_ops.py in read_variable_op(resource, dtype, name)
#     546   # Add nodes to the TensorFlow graph.
#     547   dtype = _execute.make_type(dtype, "dtype")
# --> 548   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     549         "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#     550   _result = _outputs[:]
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     776   with g.as_default(), ops.name_scope(name) as scope:
#     777     if fallback:
# --> 778       _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                              keywords, default_type_attr_map, attrs, inputs,
#     780                              input_types)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/op_def_library.py in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     549                 preferred_dtype=default_dtype)
#     550         else:
# --> 551           values = ops.convert_to_tensor(
#     552               values,
#     553               name=input_arg.name,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     730   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     731   preferred_dtype = preferred_dtype or dtype_hint
# --> 732   return tensor_conversion_registry.convert(
#     733       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     734   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207   overload = getattr(value, "__tf_tensor__", None)
#     208   if overload is not None:
# --> 209     return overload(dtype, name)  #  pylint: disable=not-callable
#     210
#     211   for base_type, conversion_func in get(type(value)):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in __tf_tensor__(self, dtype, name)
#     624                 "building a function.",
#     625                 name=name))
# --> 626       return graph.capture(self, name=name)
#     627     return super().__tf_tensor__(dtype, name)
#     628
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py in capture(self, tensor, name, shape)
#     673
#     674   def capture(self, tensor, name=None, shape=None):
# --> 675     return self._function_captures.capture_by_value(self, tensor, name)
#     676
#     677   def _validate_in_scope(self, tensor):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/core/function/capture/capture_container.py in capture_by_value(self, graph, tensor, name)
#     139
#     140       # Large EagerTensors and resources are captured with Placeholder ops
# --> 141       return self._create_placeholder_helper(graph, tensor, name)
#     142
#     143     if tensor.graph is not graph:
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/core/function/capture/capture_container.py in _create_placeholder_helper(self, graph, tensor, name)
#     283           composite_device_name=composite_device_name,
#     284       )
# --> 285       placeholder = spec.placeholder_value(placeholder_ctx)
#     286       self.add_or_replace(
#     287           key=id(tensor), external=tensor, internal=placeholder, is_by_ref=False
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor.py in placeholder_value(self, placeholder_context)
#    1034         and handle_data.shape_inference.shape_and_type
#    1035     ):
# -> 1036       handle_data_util.set_handle_data(placeholder, handle_data.shape_inference)
#    1037
#    1038     # Record the composite device as an attribute to the placeholder.
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/handle_data_util.py in set_handle_data(target_t, handle_data)
#      78     return
#      79   with target_t.graph._c_graph.get() as c_graph:
# ---> 80     pywrap_tf_session.SetHandleShapeAndType(c_graph, target_t._as_tf_output(),
#      81                                             handle_data.SerializeToString())
#      82   # pylint: enable=protected-access
#
# KeyboardInterrupt:

# %%
from tensorflow import keras
import zipfile
import os
from google.colab import files

# Step 2: Load the model
model = keras.models.load_model("2h_cnn_base5.keras", compile=True)

# Step 3: Re-declare any necessary callbacks and variables
# Recreate scheduler, alpha, beta, gamma, LossWeightsModifier, etc.

change_lr = LearningRateScheduler(scheduler)  # ensure `scheduler` is defined
change_lw = LossWeightsModifier(alpha, beta, gamma)  # ensure these vars and class exist

cbks = [change_lr, change_lw] if bt_strategy else [change_lr]

# Step 4: Resume training
history_hcnn_h_resumed = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,  # number of **additional** epochs to train
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_h_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_h_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_h_cnn_c,cons_h_cnn_c,f1_h_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("2h_cnn_base6.keras")

# Save results to file
with open('2results_h_cnn_base6.txt', 'w') as f:  # New file for B-CNN
  f.write("--- h-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_h_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_h_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_h_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_h_cnn_c}\n")
  f.write(f"Consistency: {cons_h_cnn_c}\n")
  f.write(f"F1: {f1_h_cnn_c}\n")
  f.write(f"Parameters: {parameters_h_cnn_c:,}\n")

# Define file names
model_file = "2h_cnn_base6.keras"
results_file = "2results_h_cnn_base6.txt"
zip_file = "2h_cnn_base_results6.zip"

# Create a zip archive with both files
with zipfile.ZipFile(zip_file, 'w') as zipf:
    zipf.write(model_file)
    zipf.write(results_file)

# Download the zip file to local machine
files.download(zip_file)
# Out:
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2132s 12s/step - c1_predictions_cifar10_accuracy: 0.9909 - c1_predictions_cifar10_loss: 0.0306 - c2_predictions_cifar10_accuracy: 0.9899 - c2_predictions_cifar10_loss: 0.0278 - loss: 0.0121 - predictions_cifar10_accuracy: 0.9984 - predictions_cifar10_loss: 0.0050 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0262 - val_c2_predictions_cifar10_accuracy: 0.9843 - val_c2_predictions_cifar10_loss: 0.0607 - val_loss: 0.3116 - val_predictions_cifar10_accuracy: 0.9390 - val_predictions_cifar10_loss: 0.4215 - learning_rate: 0.0010
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2145s 12s/step - c1_predictions_cifar10_accuracy: 0.9902 - c1_predictions_cifar10_loss: 0.0302 - c2_predictions_cifar10_accuracy: 0.9916 - c2_predictions_cifar10_loss: 0.0276 - loss: 0.0130 - predictions_cifar10_accuracy: 0.9981 - predictions_cifar10_loss: 0.0064 - val_c1_predictions_cifar10_accuracy: 0.9930 - val_c1_predictions_cifar10_loss: 0.0261 - val_c2_predictions_cifar10_accuracy: 0.9838 - val_c2_predictions_cifar10_loss: 0.0608 - val_loss: 0.3088 - val_predictions_cifar10_accuracy: 0.9394 - val_predictions_cifar10_loss: 0.4174 - learning_rate: 0.0010
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2154s 12s/step - c1_predictions_cifar10_accuracy: 0.9925 - c1_predictions_cifar10_loss: 0.0280 - c2_predictions_cifar10_accuracy: 0.9907 - c2_predictions_cifar10_loss: 0.0302 - loss: 0.0133 - predictions_cifar10_accuracy: 0.9987 - predictions_cifar10_loss: 0.0064 - val_c1_predictions_cifar10_accuracy: 0.9926 - val_c1_predictions_cifar10_loss: 0.0263 - val_c2_predictions_cifar10_accuracy: 0.9843 - val_c2_predictions_cifar10_loss: 0.0609 - val_loss: 0.3198 - val_predictions_cifar10_accuracy: 0.9411 - val_predictions_cifar10_loss: 0.4332 - learning_rate: 0.0010
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2103s 12s/step - c1_predictions_cifar10_accuracy: 0.9905 - c1_predictions_cifar10_loss: 0.0318 - c2_predictions_cifar10_accuracy: 0.9917 - c2_predictions_cifar10_loss: 0.0282 - loss: 0.0128 - predictions_cifar10_accuracy: 0.9981 - predictions_cifar10_loss: 0.0057 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0258 - val_c2_predictions_cifar10_accuracy: 0.9845 - val_c2_predictions_cifar10_loss: 0.0612 - val_loss: 0.3205 - val_predictions_cifar10_accuracy: 0.9377 - val_predictions_cifar10_loss: 0.4340 - learning_rate: 0.0010
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2146s 12s/step - c1_predictions_cifar10_accuracy: 0.9916 - c1_predictions_cifar10_loss: 0.0270 - c2_predictions_cifar10_accuracy: 0.9913 - c2_predictions_cifar10_loss: 0.0258 - loss: 0.0098 - predictions_cifar10_accuracy: 0.9994 - predictions_cifar10_loss: 0.0028 - val_c1_predictions_cifar10_accuracy: 0.9930 - val_c1_predictions_cifar10_loss: 0.0258 - val_c2_predictions_cifar10_accuracy: 0.9849 - val_c2_predictions_cifar10_loss: 0.0613 - val_loss: 0.3194 - val_predictions_cifar10_accuracy: 0.9388 - val_predictions_cifar10_loss: 0.4323 - learning_rate: 0.0010
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2150s 12s/step - c1_predictions_cifar10_accuracy: 0.9917 - c1_predictions_cifar10_loss: 0.0298 - c2_predictions_cifar10_accuracy: 0.9920 - c2_predictions_cifar10_loss: 0.0254 - loss: 0.0109 - predictions_cifar10_accuracy: 0.9984 - predictions_cifar10_loss: 0.0041 - val_c1_predictions_cifar10_accuracy: 0.9934 - val_c1_predictions_cifar10_loss: 0.0254 - val_c2_predictions_cifar10_accuracy: 0.9851 - val_c2_predictions_cifar10_loss: 0.0620 - val_loss: 0.3121 - val_predictions_cifar10_accuracy: 0.9416 - val_predictions_cifar10_loss: 0.4219 - learning_rate: 0.0010
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2145s 12s/step - c1_predictions_cifar10_accuracy: 0.9918 - c1_predictions_cifar10_loss: 0.0301 - c2_predictions_cifar10_accuracy: 0.9920 - c2_predictions_cifar10_loss: 0.0268 - loss: 0.0116 - predictions_cifar10_accuracy: 0.9991 - predictions_cifar10_loss: 0.0046 - val_c1_predictions_cifar10_accuracy: 0.9934 - val_c1_predictions_cifar10_loss: 0.0251 - val_c2_predictions_cifar10_accuracy: 0.9847 - val_c2_predictions_cifar10_loss: 0.0625 - val_loss: 0.3191 - val_predictions_cifar10_accuracy: 0.9390 - val_predictions_cifar10_loss: 0.4317 - learning_rate: 0.0010
# Epoch 8/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2125s 12s/step - c1_predictions_cifar10_accuracy: 0.9916 - c1_predictions_cifar10_loss: 0.0278 - c2_predictions_cifar10_accuracy: 0.9921 - c2_predictions_cifar10_loss: 0.0236 - loss: 0.0095 - predictions_cifar10_accuracy: 0.9991 - predictions_cifar10_loss: 0.0028 - val_c1_predictions_cifar10_accuracy: 0.9936 - val_c1_predictions_cifar10_loss: 0.0246 - val_c2_predictions_cifar10_accuracy: 0.9847 - val_c2_predictions_cifar10_loss: 0.0601 - val_loss: 0.3210 - val_predictions_cifar10_accuracy: 0.9416 - val_predictions_cifar10_loss: 0.4350 - learning_rate: 0.0010
# Epoch 9/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2061s 12s/step - c1_predictions_cifar10_accuracy: 0.9914 - c1_predictions_cifar10_loss: 0.0262 - c2_predictions_cifar10_accuracy: 0.9952 - c2_predictions_cifar10_loss: 0.0181 - loss: 0.0098 - predictions_cifar10_accuracy: 0.9981 - predictions_cifar10_loss: 0.0052 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0245 - val_c2_predictions_cifar10_accuracy: 0.9855 - val_c2_predictions_cifar10_loss: 0.0614 - val_loss: 0.3257 - val_predictions_cifar10_accuracy: 0.9396 - val_predictions_cifar10_loss: 0.4414 - learning_rate: 0.0010
# Epoch 10/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2071s 12s/step - c1_predictions_cifar10_accuracy: 0.9919 - c1_predictions_cifar10_loss: 0.0264 - c2_predictions_cifar10_accuracy: 0.9933 - c2_predictions_cifar10_loss: 0.0229 - loss: 0.0102 - predictions_cifar10_accuracy: 0.9987 - predictions_cifar10_loss: 0.0043 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0245 - val_c2_predictions_cifar10_accuracy: 0.9843 - val_c2_predictions_cifar10_loss: 0.0603 - val_loss: 0.3171 - val_predictions_cifar10_accuracy: 0.9390 - val_predictions_cifar10_loss: 0.4296 - learning_rate: 0.0010
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 55s 369ms/step

# %% [markdown]
# # B-CNN

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper


img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(512, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(512, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(coarse1_classes, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(1024, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(1024, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(coarse2_classes, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(4096, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bcnn_base_c')
model.load_weights(weights_path, by_name=True)
#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'],
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy','accuracy','accuracy'])
model.summary()
# Out:
# Model: "bcnn_base_c"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 32, 32, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 32, 32,    │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 32, 32,    │     36,928 │ batch_normalizat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 16, 16,    │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ block2_conv1[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 16, 16,    │    147,584 │ batch_normalizat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ block2_conv2[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 8, 8, 256) │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ block3_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 4, 4, 512) │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ block4_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 2, 2, 512) │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ block5_conv3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_flatten          │ (None, 8192)      │          0 │ block2_pool[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_flatten          │ (None, 4096)      │          0 │ block3_pool[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fc_cifar10_1     │ (None, 512)       │  4,194,816 │ c1_flatten[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fc_cifar10_1     │ (None, 1024)      │  4,195,328 │ c2_flatten[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc_cifar10_1        │ (None, 4096)      │  8,392,704 │ flatten[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ c1_fc_cifar10_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ c2_fc_cifar10_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4096)      │     16,384 │ fc_cifar10_1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1024)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4096)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fc2 (Dense)      │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fc2 (Dense)      │ (None, 1024)      │  1,049,600 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2 (Dense)         │ (None, 4096)      │ 16,781,312 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ c1_fc2[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ c2_fc2[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4096)      │     16,384 │ fc2[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 1024)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4096)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_predictions_cif… │ (None, 4)         │      2,052 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_predictions_cif… │ (None, 12)        │     12,300 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions_cifar10 │ (None, 30)        │    122,910 │ dropout_5[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 49,790,318 (189.93 MB)
#  Trainable params: 49,759,342 (189.82 MB)
#  Non-trainable params: 30,976 (121.00 KB)

# %%
import zipfile
import os
from google.colab import files

# Callbacks
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_b_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_b_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_b_cnn_c,cons_b_cnn_c,f1_b_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("b_cnn_base.keras")

# Save results to file
with open('results_b_cnn_base.txt', 'w') as f:  # New file for B-CNN
  f.write("--- B-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_b_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_b_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_b_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_b_cnn_c}\n")
  f.write(f"Consistency: {cons_b_cnn_c}\n")
  f.write(f"F1: {f1_b_cnn_c}\n")
  f.write(f"Parameters: {parameters_b_cnn_c:,}\n")

# Define file names
model_file = "b_cnn_base.keras"
results_file = "results_b_cnn_base.txt"
zip_file = "b_cnn_base_results.zip"

# Create a zip archive with both files
with zipfile.ZipFile(zip_file, 'w') as zipf:
    zipf.write(model_file)
    zipf.write(results_file)

# Download the zip file to local machine
files.download(zip_file)

# Results
print("--- B-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_b_cnn_c[4])
print("Accuracy level 2:",score_b_cnn_c[5])
print("Accuracy level 3:",score_b_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Accuracy:",acc_b_cnn_c)
print("Consistency:",cons_b_cnn_c)
print("f1:",f1_b_cnn_c)
print("Parameters:","{:,}".format(parameters_b_cnn_c))
# Out:
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2528s 15s/step - c1_predictions_cifar10_accuracy: 0.8123 - c1_predictions_cifar10_loss: 0.5763 - c2_predictions_cifar10_accuracy: 0.1405 - c2_predictions_cifar10_loss: 3.4208 - loss: 0.6403 - predictions_cifar10_accuracy: 0.1337 - predictions_cifar10_loss: 4.1289 - val_c1_predictions_cifar10_accuracy: 0.9773 - val_c1_predictions_cifar10_loss: 0.0697 - val_c2_predictions_cifar10_accuracy: 0.6272 - val_c2_predictions_cifar10_loss: 1.2618 - val_loss: 0.1059 - val_predictions_cifar10_accuracy: 0.3237 - val_predictions_cifar10_loss: 2.4785 - learning_rate: 0.0010
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2594s 15s/step - c1_predictions_cifar10_accuracy: 0.9636 - c1_predictions_cifar10_loss: 0.1119 - c2_predictions_cifar10_accuracy: 0.3841 - c2_predictions_cifar10_loss: 2.1684 - loss: 0.1511 - predictions_cifar10_accuracy: 0.4845 - predictions_cifar10_loss: 1.9771 - val_c1_predictions_cifar10_accuracy: 0.9864 - val_c1_predictions_cifar10_loss: 0.0442 - val_c2_predictions_cifar10_accuracy: 0.7279 - val_c2_predictions_cifar10_loss: 0.9586 - val_loss: 0.0630 - val_predictions_cifar10_accuracy: 0.7116 - val_predictions_cifar10_loss: 1.0010 - learning_rate: 0.0010
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2604s 15s/step - c1_predictions_cifar10_accuracy: 0.9759 - c1_predictions_cifar10_loss: 0.0778 - c2_predictions_cifar10_accuracy: 0.5233 - c2_predictions_cifar10_loss: 1.6565 - loss: 0.1078 - predictions_cifar10_accuracy: 0.5938 - predictions_cifar10_loss: 1.4992 - val_c1_predictions_cifar10_accuracy: 0.9902 - val_c1_predictions_cifar10_loss: 0.0359 - val_c2_predictions_cifar10_accuracy: 0.7828 - val_c2_predictions_cifar10_loss: 0.7806 - val_loss: 0.0513 - val_predictions_cifar10_accuracy: 0.7515 - val_predictions_cifar10_loss: 0.8292 - learning_rate: 0.0010
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2610s 15s/step - c1_predictions_cifar10_accuracy: 0.9832 - c1_predictions_cifar10_loss: 0.0559 - c2_predictions_cifar10_accuracy: 0.6147 - c2_predictions_cifar10_loss: 1.3228 - loss: 0.0806 - predictions_cifar10_accuracy: 0.6459 - predictions_cifar10_loss: 1.2551 - val_c1_predictions_cifar10_accuracy: 0.9904 - val_c1_predictions_cifar10_loss: 0.0324 - val_c2_predictions_cifar10_accuracy: 0.8130 - val_c2_predictions_cifar10_loss: 0.6669 - val_loss: 0.0459 - val_predictions_cifar10_accuracy: 0.7800 - val_predictions_cifar10_loss: 0.7413 - learning_rate: 0.0010
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2662s 15s/step - c1_predictions_cifar10_accuracy: 0.9843 - c1_predictions_cifar10_loss: 0.0521 - c2_predictions_cifar10_accuracy: 0.6661 - c2_predictions_cifar10_loss: 1.1613 - loss: 0.0739 - predictions_cifar10_accuracy: 0.6814 - predictions_cifar10_loss: 1.1285 - val_c1_predictions_cifar10_accuracy: 0.9913 - val_c1_predictions_cifar10_loss: 0.0293 - val_c2_predictions_cifar10_accuracy: 0.8353 - val_c2_predictions_cifar10_loss: 0.5869 - val_loss: 0.0415 - val_predictions_cifar10_accuracy: 0.7962 - val_predictions_cifar10_loss: 0.6896 - learning_rate: 0.0010
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2671s 15s/step - c1_predictions_cifar10_accuracy: 0.9879 - c1_predictions_cifar10_loss: 0.0402 - c2_predictions_cifar10_accuracy: 0.7029 - c2_predictions_cifar10_loss: 1.0253 - loss: 0.0599 - predictions_cifar10_accuracy: 0.7060 - predictions_cifar10_loss: 1.0286 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0273 - val_c2_predictions_cifar10_accuracy: 0.8542 - val_c2_predictions_cifar10_loss: 0.5314 - val_loss: 0.0386 - val_predictions_cifar10_accuracy: 0.8079 - val_predictions_cifar10_loss: 0.6490 - learning_rate: 0.0010
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2648s 15s/step - c1_predictions_cifar10_accuracy: 0.9897 - c1_predictions_cifar10_loss: 0.0325 - c2_predictions_cifar10_accuracy: 0.7263 - c2_predictions_cifar10_loss: 0.9330 - loss: 0.0506 - predictions_cifar10_accuracy: 0.7249 - predictions_cifar10_loss: 0.9428 - val_c1_predictions_cifar10_accuracy: 0.9932 - val_c1_predictions_cifar10_loss: 0.0259 - val_c2_predictions_cifar10_accuracy: 0.8663 - val_c2_predictions_cifar10_loss: 0.4863 - val_loss: 0.0363 - val_predictions_cifar10_accuracy: 0.8230 - val_predictions_cifar10_loss: 0.6069 - learning_rate: 0.0010
# Epoch 8/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2628s 15s/step - c1_predictions_cifar10_accuracy: 0.9916 - c1_predictions_cifar10_loss: 0.0304 - c2_predictions_cifar10_accuracy: 0.7450 - c2_predictions_cifar10_loss: 0.8732 - loss: 0.0477 - predictions_cifar10_accuracy: 0.7356 - predictions_cifar10_loss: 0.9231 - val_c1_predictions_cifar10_accuracy: 0.9930 - val_c1_predictions_cifar10_loss: 0.0262 - val_c2_predictions_cifar10_accuracy: 0.8744 - val_c2_predictions_cifar10_loss: 0.4527 - val_loss: 0.0361 - val_predictions_cifar10_accuracy: 0.8274 - val_predictions_cifar10_loss: 0.5836 - learning_rate: 0.0010
# Epoch 9/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2637s 15s/step - c1_predictions_cifar10_accuracy: 0.9919 - c1_predictions_cifar10_loss: 0.0246 - c2_predictions_cifar10_accuracy: 0.7670 - c2_predictions_cifar10_loss: 0.8073 - loss: 0.0406 - predictions_cifar10_accuracy: 0.7560 - predictions_cifar10_loss: 0.8411 - val_c1_predictions_cifar10_accuracy: 0.9936 - val_c1_predictions_cifar10_loss: 0.0246 - val_c2_predictions_cifar10_accuracy: 0.8818 - val_c2_predictions_cifar10_loss: 0.4268 - val_loss: 0.0340 - val_predictions_cifar10_accuracy: 0.8346 - val_predictions_cifar10_loss: 0.5579 - learning_rate: 0.0010
# Epoch 10/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2561s 15s/step - c1_predictions_cifar10_accuracy: 0.9929 - c1_predictions_cifar10_loss: 0.0234 - c2_predictions_cifar10_accuracy: 0.7803 - c2_predictions_cifar10_loss: 0.7614 - loss: 0.0386 - predictions_cifar10_accuracy: 0.7678 - predictions_cifar10_loss: 0.8034 - val_c1_predictions_cifar10_accuracy: 0.9938 - val_c1_predictions_cifar10_loss: 0.0243 - val_c2_predictions_cifar10_accuracy: 0.8897 - val_c2_predictions_cifar10_loss: 0.4035 - val_loss: 0.0333 - val_predictions_cifar10_accuracy: 0.8423 - val_predictions_cifar10_loss: 0.5373 - learning_rate: 0.0010
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 63s 424ms/step
# --- B-CNN Base C ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9938363432884216
# Accuracy level 2: 0.8896918296813965
# Accuracy level 3: 0.8422954082489014
# --- Hierarchical Metrics ---
# Accuracy: 0.7781083953241232
# Consistency: 0.8831030818278427
# f1: 0.9097869625323456
# Parameters: 49,759,342

# %%
from tensorflow import keras

# Step 2: Load the model
model = keras.models.load_model("b_cnn_base.keras", compile=True)

# Step 3: Re-declare any necessary callbacks and variables
# Recreate scheduler, alpha, beta, gamma, LossWeightsModifier, etc.

change_lr = LearningRateScheduler(scheduler)  # ensure `scheduler` is defined
change_lw = LossWeightsModifier(alpha, beta, gamma)  # ensure these vars and class exist

cbks = [change_lr, change_lw] if bt_strategy else [change_lr]

# Step 4: Resume training
history_bcnn_b_resumed = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,  # number of **additional** epochs to train
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_b_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_b_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_b_cnn_c,cons_b_cnn_c,f1_b_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("b_cnn_base2.keras")

# Save results to file
with open('results_b_cnn_base2.txt', 'w') as f:  # New file for B-CNN
  f.write("--- B-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_b_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_b_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_b_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_b_cnn_c}\n")
  f.write(f"Consistency: {cons_b_cnn_c}\n")
  f.write(f"F1: {f1_b_cnn_c}\n")
  f.write(f"Parameters: {parameters_b_cnn_c:,}\n")

# Define file names
model_file = "b_cnn_base2.keras"
results_file = "results_b_cnn_base2.txt"
zip_file = "b_cnn_base_results2.zip"

# Create a zip archive with both files
with zipfile.ZipFile(zip_file, 'w') as zipf:
    zipf.write(model_file)
    zipf.write(results_file)

# Download the zip file to local machine
files.download(zip_file)
# Out:
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2595s 15s/step - c1_predictions_cifar10_accuracy: 0.9929 - c1_predictions_cifar10_loss: 0.0219 - c2_predictions_cifar10_accuracy: 0.8037 - c2_predictions_cifar10_loss: 0.6815 - loss: 0.0359 - predictions_cifar10_accuracy: 0.7730 - predictions_cifar10_loss: 0.7601 - val_c1_predictions_cifar10_accuracy: 0.9947 - val_c1_predictions_cifar10_loss: 0.0241 - val_c2_predictions_cifar10_accuracy: 0.8952 - val_c2_predictions_cifar10_loss: 0.3826 - val_loss: 0.0327 - val_predictions_cifar10_accuracy: 0.8470 - val_predictions_cifar10_loss: 0.5228 - learning_rate: 0.0010
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2657s 15s/step - c1_predictions_cifar10_accuracy: 0.9954 - c1_predictions_cifar10_loss: 0.0171 - c2_predictions_cifar10_accuracy: 0.7994 - c2_predictions_cifar10_loss: 0.6736 - loss: 0.0308 - predictions_cifar10_accuracy: 0.7840 - predictions_cifar10_loss: 0.7362 - val_c1_predictions_cifar10_accuracy: 0.9940 - val_c1_predictions_cifar10_loss: 0.0235 - val_c2_predictions_cifar10_accuracy: 0.8995 - val_c2_predictions_cifar10_loss: 0.3669 - val_loss: 0.0319 - val_predictions_cifar10_accuracy: 0.8516 - val_predictions_cifar10_loss: 0.5059 - learning_rate: 0.0010
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2678s 15s/step - c1_predictions_cifar10_accuracy: 0.9953 - c1_predictions_cifar10_loss: 0.0176 - c2_predictions_cifar10_accuracy: 0.8119 - c2_predictions_cifar10_loss: 0.6376 - loss: 0.0307 - predictions_cifar10_accuracy: 0.7885 - predictions_cifar10_loss: 0.7124 - val_c1_predictions_cifar10_accuracy: 0.9940 - val_c1_predictions_cifar10_loss: 0.0244 - val_c2_predictions_cifar10_accuracy: 0.9035 - val_c2_predictions_cifar10_loss: 0.3498 - val_loss: 0.0324 - val_predictions_cifar10_accuracy: 0.8553 - val_predictions_cifar10_loss: 0.4933 - learning_rate: 0.0010
# Epoch 4/10
# 105/172 ━━━━━━━━━━━━━━━━━━━━ 16:54 15s/step - c1_predictions_cifar10_accuracy: 0.9949 - c1_predictions_cifar10_loss: 0.0170 - c2_predictions_cifar10_accuracy: 0.8149 - c2_predictions_cifar10_loss: 0.6511 - loss: 0.0302 - predictions_cifar10_accuracy: 0.7880 - predictions_cifar10_loss: 0.7116

# %%
from tensorflow import keras

# Step 2: Load the model
model = keras.models.load_model("b_cnn_base2.keras", compile=True)

# Step 3: Re-declare any necessary callbacks and variables
# Recreate scheduler, alpha, beta, gamma, LossWeightsModifier, etc.

change_lr = LearningRateScheduler(scheduler)  # ensure `scheduler` is defined
change_lw = LossWeightsModifier(alpha, beta, gamma)  # ensure these vars and class exist

cbks = [change_lr, change_lw] if bt_strategy else [change_lr]

# Step 4: Resume training
history_bcnn_b_resumed = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,  # number of **additional** epochs to train
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_b_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_b_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_b_cnn_c,cons_b_cnn_c,f1_b_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("b_cnn_base3.keras")

# Save results to file
with open('results_b_cnn_base3.txt', 'w') as f:  # New file for B-CNN
  f.write("--- B-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_b_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_b_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_b_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_b_cnn_c}\n")
  f.write(f"Consistency: {cons_b_cnn_c}\n")
  f.write(f"F1: {f1_b_cnn_c}\n")
  f.write(f"Parameters: {parameters_b_cnn_c:,}\n")

# Define file names
model_file = "b_cnn_base3.keras"
results_file = "results_b_cnn_base3.txt"
zip_file = "b_cnn_base_results3.zip"

# Create a zip archive with both files
with zipfile.ZipFile(zip_file, 'w') as zipf:
    zipf.write(model_file)
    zipf.write(results_file)

# Download the zip file to local machine
files.download(zip_file)

# %% [markdown]
# # BA-CNN

# %%
# Best Hypeparameters
# if True, the model uses BT-strategy for training
bt_strategy = True

# neurons of all dense layers on each branch
branch_neurons = 16    # Parsimonious version 256

att_neurons = 2048     # Parsimonious version 64

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper

img_input = Input(shape=input_shape, name='input')
#block 1
x = Conv2D(64, (3, 3), activation='relu', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)

#block 2
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)

#coarse 1
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(branch_neurons, activation='relu')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(branch_neurons, activation='relu')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
#c_1_pred = Dense(coarse1_classes, activation='softmax')(c_1_bch)

#block 3
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)

#coarse 2
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(branch_neurons, activation='relu')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(branch_neurons, activation='relu')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)


#block 4
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)


#block 5
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)

#fine
x = Flatten(name='flatten')(x)
x = Dense(branch_neurons, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(branch_neurons, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

#-- Att for coarse 1---
# Coarse 1
sfcn_1_1 = Dense(att_neurons, name='fc1_1')(c_1_bch)
sfcn_1_1 = Dense(1, name='fc1_2')(sfcn_1_1)
# Coarse 2
sfcn_1_2 = Dense(att_neurons, name='fc1_3')(c_2_bch)
sfcn_1_2 = Dense(1, name='fc1_4')(sfcn_1_2)
# Fine
sfcn_1_3 = Dense(att_neurons, name='fc1_5')(x)
sfcn_1_3 = Dense(1, name='fc1_6')(sfcn_1_3)

score_vector_1 = Concatenate()([sfcn_1_1,sfcn_1_2,sfcn_1_3]) # Score vector 1
att_weights_1 = Activation('softmax', name='attention_weights_1')(score_vector_1) # Attention weights 1

weighted_c1_bch_1 = Multiply()([c_1_bch, att_weights_1[:, 0:1]])
weighted_c2_bch_1 = Multiply()([c_2_bch, att_weights_1[:, 1:2]])
weighted_x_1 = Multiply()([x, att_weights_1[:, 2:3]])

weightned_sum_1 = Add()([weighted_c1_bch_1, weighted_c2_bch_1, weighted_x_1]) # Weightned sum 1

# Concat and prediction
coarse_1_concat = Concatenate()([c_1_bch,weightned_sum_1])
c_1_pred = Dense(coarse1_classes, activation='softmax', name='c1_predictions_cifar100')(coarse_1_concat)

#-- Att for coarse 2---

# Coarse 1
sfcn_2_1 = Dense(att_neurons, name='fc2_1')(c_1_bch)
sfcn_2_1 = Dense(1, name='fc2_2')(sfcn_2_1)
# Coarse 2
sfcn_2_2 = Dense(att_neurons, name='fc2_3')(c_2_bch)
sfcn_2_2 = Dense(1, name='fc2_4')(sfcn_2_2)
# Fine
sfcn_2_3 = Dense(att_neurons, name='fc2_5')(x)
sfcn_2_3 = Dense(1, name='fc2_6')(sfcn_2_3)

score_vector_2 = Concatenate()([sfcn_2_1,sfcn_2_2,sfcn_2_3]) # Score vector 1
att_weights_2 = Activation('softmax', name='attention_weights_2')(score_vector_2) # Attention weights 1

weighted_c1_bch_2 = Multiply()([c_1_bch, att_weights_2[:, 0:1]])
weighted_c2_bch_2 = Multiply()([c_2_bch, att_weights_2[:, 1:2]])
weighted_x_2 = Multiply()([x, att_weights_2[:, 2:3]])

weightned_sum_2 = Add()([weighted_c1_bch_2, weighted_c2_bch_2, weighted_x_2]) # Weightned sum 1

# Concat and prediction
coarse_2_concat = Concatenate()([c_2_bch,weightned_sum_2])
c_2_pred = Dense(coarse2_classes, activation='softmax', name='c2_predictions_cifar100')(coarse_2_concat)

#-- Att for fine---
# Coarse 1
sfcn_3_1 = Dense(att_neurons, name='fc3_1')(c_1_bch)
sfcn_3_1 = Dense(1, name='fc3_2')(sfcn_3_1)
# Coarse 2
sfcn_3_2 = Dense(att_neurons, name='fc3_3')(c_2_bch)
sfcn_3_2 = Dense(1, name='fc3_4')(sfcn_3_2)
# Fine
sfcn_3_3 = Dense(att_neurons, name='fc3_5')(x)
sfcn_3_3 = Dense(1, name='fc3_6')(sfcn_3_3)

score_vector_3 = Concatenate()([sfcn_3_1,sfcn_3_2,sfcn_3_3]) # Score vector 1
att_weights_3 = Activation('softmax', name='attention_weights_3')(score_vector_3) # Attention weights 1

weighted_c1_bch_3 = Multiply()([c_1_bch, att_weights_3[:, 0:1]])
weighted_c2_bch_3 = Multiply()([c_2_bch, att_weights_3[:, 1:2]])
weighted_x_3 = Multiply()([x, att_weights_3[:, 2:3]])

weightned_sum_3 = Add()([weighted_c1_bch_3, weighted_c2_bch_3, weighted_x_3]) # Weightned sum 3

# Concat and prediction
fine_concat = Concatenate()([x,weightned_sum_3])
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar100')(fine_concat)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bacnn')

#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'],
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy', 'accuracy', 'accuracy'])
model.summary()
# Out:
# Model: "bacnn"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 32, 32, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      1,792 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 4, 4, 512) │  1,180,160 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 4, 4, 512) │  2,359,808 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_flatten          │ (None, 8192)      │          0 │ max_pooling2d_1[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_flatten          │ (None, 4096)      │          0 │ max_pooling2d_2[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │    131,088 │ c1_flatten[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │     65,552 │ c2_flatten[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │     32,784 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │        272 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 16)        │        272 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 16)        │        272 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_1 (Dense)       │ (None, 2048)      │     34,816 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_3 (Dense)       │ (None, 2048)      │     34,816 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_5 (Dense)       │ (None, 2048)      │     34,816 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_1 (Dense)       │ (None, 2048)      │     34,816 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_3 (Dense)       │ (None, 2048)      │     34,816 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_5 (Dense)       │ (None, 2048)      │     34,816 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_1 (Dense)       │ (None, 2048)      │     34,816 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_3 (Dense)       │ (None, 2048)      │     34,816 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_5 (Dense)       │ (None, 2048)      │     34,816 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_2 (Dense)       │ (None, 1)         │      2,049 │ fc1_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_4 (Dense)       │ (None, 1)         │      2,049 │ fc1_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1_6 (Dense)       │ (None, 1)         │      2,049 │ fc1_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_2 (Dense)       │ (None, 1)         │      2,049 │ fc2_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_4 (Dense)       │ (None, 1)         │      2,049 │ fc2_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2_6 (Dense)       │ (None, 1)         │      2,049 │ fc2_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_2 (Dense)       │ (None, 1)         │      2,049 │ fc3_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_4 (Dense)       │ (None, 1)         │      2,049 │ fc3_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc3_6 (Dense)       │ (None, 1)         │      2,049 │ fc3_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 3)         │          0 │ fc1_2[0][0],      │
# │ (Concatenate)       │                   │            │ fc1_4[0][0],      │
# │                     │                   │            │ fc1_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 3)         │          0 │ fc2_2[0][0],      │
# │ (Concatenate)       │                   │            │ fc2_4[0][0],      │
# │                     │                   │            │ fc2_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 3)         │          0 │ fc3_2[0][0],      │
# │ (Concatenate)       │                   │            │ fc3_4[0][0],      │
# │                     │                   │            │ fc3_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights_1 │ (None, 3)         │          0 │ concatenate[0][0] │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights_2 │ (None, 3)         │          0 │ concatenate_2[0]… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights_3 │ (None, 3)         │          0 │ concatenate_4[0]… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 1)         │          0 │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 1)         │          0 │ attention_weight… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16)        │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ get_item[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16)        │          0 │ dropout_3[0][0],  │
# │ (Multiply)          │                   │            │ get_item_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16)        │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 16)        │          0 │ dropout_1[0][0],  │
# │ (Multiply)          │                   │            │ get_item_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16)        │          0 │ dropout_3[0][0],  │
# │ (Multiply)          │                   │            │ get_item_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 16)        │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ get_item_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 16)        │          0 │ dropout_1[0][0],  │
# │ (Multiply)          │                   │            │ get_item_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 16)        │          0 │ dropout_3[0][0],  │
# │ (Multiply)          │                   │            │ get_item_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 16)        │          0 │ dropout_5[0][0],  │
# │ (Multiply)          │                   │            │ get_item_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16)        │          0 │ multiply[0][0],   │
# │                     │                   │            │ multiply_1[0][0], │
# │                     │                   │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16)        │          0 │ multiply_3[0][0], │
# │                     │                   │            │ multiply_4[0][0], │
# │                     │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16)        │          0 │ multiply_6[0][0], │
# │                     │                   │            │ multiply_7[0][0], │
# │                     │                   │            │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32)        │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 32)        │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32)        │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_predictions_cif… │ (None, 4)         │        132 │ concatenate_1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_predictions_cif… │ (None, 12)        │        396 │ concatenate_3[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions_cifar1… │ (None, 30)        │        990 │ concatenate_5[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,295,511 (58.35 MB)
#  Trainable params: 15,286,871 (58.31 MB)
#  Non-trainable params: 8,640 (33.75 KB)

# %%
 # Callbacks
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=cbks,
          validation_data=(x_val, [y_c1_val, y_c2_val, y_val])
,)

score_ba_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_ba_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
acc_ba_cnn_c,cons_ba_cnn_c,f1_ba_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Save model
model.save("ba_cnn_base.keras")

# Save results to file
with open('results_ba_cnn_base.txt', 'w') as f:  # New file for BA-CNN
  f.write("--- BA-CNN Base C ---\n")
  f.write(f"Accuracy level 1: {score_ba_cnn_c[4]}\n")
  f.write(f"Accuracy level 2: {score_ba_cnn_c[5]}\n")
  f.write(f"Accuracy level 3: {score_ba_cnn_c[6]}\n")
  f.write(f"Hierarchical Accuracy: {acc_ba_cnn_c}\n")
  f.write(f"Consistency: {cons_ba_cnn_c}\n")
  f.write(f"F1: {f1_ba_cnn_c}\n")
  f.write(f"Parameters: {parameters_ba_cnn_c:,}\n")

# Results
print("--- BA-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_ba_cnn_c[4])
print("Accuracy level 2:",score_ba_cnn_c[5])
print("Accuracy level 3:",score_ba_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Accuracy:",acc_ba_cnn_c)
print("Consistency:",cons_ba_cnn_c)
print("f1:",f1_ba_cnn_c)
print("Parameters:","{:,}".format(parameters_ba_cnn_c))
# Out:
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1402s 8s/step - c1_predictions_cifar100_accuracy: 0.6940 - c1_predictions_cifar100_loss: 0.8442 - c2_predictions_cifar100_accuracy: 0.1009 - c2_predictions_cifar100_loss: 3.0954 - loss: 0.8986 - predictions_cifar100_accuracy: 0.0341 - predictions_cifar100_loss: 4.0304 - val_c1_predictions_cifar100_accuracy: 0.7170 - val_c1_predictions_cifar100_loss: 0.8840 - val_c2_predictions_cifar100_accuracy: 0.1588 - val_c2_predictions_cifar100_loss: 2.7921 - val_loss: 0.9248 - val_predictions_cifar100_accuracy: 0.0068 - val_predictions_cifar100_loss: 3.3905 - learning_rate: 0.0010
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1457s 8s/step - c1_predictions_cifar100_accuracy: 0.9252 - c1_predictions_cifar100_loss: 0.2719 - c2_predictions_cifar100_accuracy: 0.1029 - c2_predictions_cifar100_loss: 3.0378 - loss: 0.3365 - predictions_cifar100_accuracy: 0.0389 - predictions_cifar100_loss: 3.9662 - val_c1_predictions_cifar100_accuracy: 0.9632 - val_c1_predictions_cifar100_loss: 0.1968 - val_c2_predictions_cifar100_accuracy: 0.0710 - val_c2_predictions_cifar100_loss: 2.3935 - val_loss: 0.2498 - val_predictions_cifar100_accuracy: 0.0274 - val_predictions_cifar100_loss: 3.4418 - learning_rate: 0.0010
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1460s 8s/step - c1_predictions_cifar100_accuracy: 0.9590 - c1_predictions_cifar100_loss: 0.1734 - c2_predictions_cifar100_accuracy: 0.1178 - c2_predictions_cifar100_loss: 2.9436 - loss: 0.2386 - predictions_cifar100_accuracy: 0.0396 - predictions_cifar100_loss: 3.9215 - val_c1_predictions_cifar100_accuracy: 0.9807 - val_c1_predictions_cifar100_loss: 0.0816 - val_c2_predictions_cifar100_accuracy: 0.0576 - val_c2_predictions_cifar100_loss: 2.3794 - val_loss: 0.1383 - val_predictions_cifar100_accuracy: 0.0604 - val_predictions_cifar100_loss: 3.4933 - learning_rate: 0.0010
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1442s 8s/step - c1_predictions_cifar100_accuracy: 0.9659 - c1_predictions_cifar100_loss: 0.1337 - c2_predictions_cifar100_accuracy: 0.1292 - c2_predictions_cifar100_loss: 2.8767 - loss: 0.1988 - predictions_cifar100_accuracy: 0.0439 - predictions_cifar100_loss: 3.9033 - val_c1_predictions_cifar100_accuracy: 0.9845 - val_c1_predictions_cifar100_loss: 0.0592 - val_c2_predictions_cifar100_accuracy: 0.0712 - val_c2_predictions_cifar100_loss: 2.3686 - val_loss: 0.1156 - val_predictions_cifar100_accuracy: 0.0674 - val_predictions_cifar100_loss: 3.4401 - learning_rate: 0.0010
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1456s 8s/step - c1_predictions_cifar100_accuracy: 0.9760 - c1_predictions_cifar100_loss: 0.1072 - c2_predictions_cifar100_accuracy: 0.1446 - c2_predictions_cifar100_loss: 2.8045 - loss: 0.1715 - predictions_cifar100_accuracy: 0.0507 - predictions_cifar100_loss: 3.8440 - val_c1_predictions_cifar100_accuracy: 0.9879 - val_c1_predictions_cifar100_loss: 0.0469 - val_c2_predictions_cifar100_accuracy: 0.0969 - val_c2_predictions_cifar100_loss: 2.2962 - val_loss: 0.1029 - val_predictions_cifar100_accuracy: 0.0759 - val_predictions_cifar100_loss: 3.4157 - learning_rate: 0.0010
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1475s 8s/step - c1_predictions_cifar100_accuracy: 0.9788 - c1_predictions_cifar100_loss: 0.0907 - c2_predictions_cifar100_accuracy: 0.1472 - c2_predictions_cifar100_loss: 2.7729 - loss: 0.1548 - predictions_cifar100_accuracy: 0.0563 - predictions_cifar100_loss: 3.8221 - val_c1_predictions_cifar100_accuracy: 0.9885 - val_c1_predictions_cifar100_loss: 0.0421 - val_c2_predictions_cifar100_accuracy: 0.0651 - val_c2_predictions_cifar100_loss: 2.2800 - val_loss: 0.0983 - val_predictions_cifar100_accuracy: 0.0659 - val_predictions_cifar100_loss: 3.4562 - learning_rate: 0.0010
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1469s 8s/step - c1_predictions_cifar100_accuracy: 0.9814 - c1_predictions_cifar100_loss: 0.0799 - c2_predictions_cifar100_accuracy: 0.1613 - c2_predictions_cifar100_loss: 2.6829 - loss: 0.1430 - predictions_cifar100_accuracy: 0.0583 - predictions_cifar100_loss: 3.7931 - val_c1_predictions_cifar100_accuracy: 0.9855 - val_c1_predictions_cifar100_loss: 0.0538 - val_c2_predictions_cifar100_accuracy: 0.1146 - val_c2_predictions_cifar100_loss: 2.1995 - val_loss: 0.1080 - val_predictions_cifar100_accuracy: 0.0759 - val_predictions_cifar100_loss: 3.3656 - learning_rate: 0.0010
# Epoch 8/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1456s 8s/step - c1_predictions_cifar100_accuracy: 0.9833 - c1_predictions_cifar100_loss: 0.0754 - c2_predictions_cifar100_accuracy: 0.1764 - c2_predictions_cifar100_loss: 2.6336 - loss: 0.1380 - predictions_cifar100_accuracy: 0.0645 - predictions_cifar100_loss: 3.7753 - val_c1_predictions_cifar100_accuracy: 0.9887 - val_c1_predictions_cifar100_loss: 0.0421 - val_c2_predictions_cifar100_accuracy: 0.2727 - val_c2_predictions_cifar100_loss: 2.0655 - val_loss: 0.0946 - val_predictions_cifar100_accuracy: 0.0787 - val_predictions_cifar100_loss: 3.2919 - learning_rate: 0.0010
# Epoch 9/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1441s 8s/step - c1_predictions_cifar100_accuracy: 0.9866 - c1_predictions_cifar100_loss: 0.0620 - c2_predictions_cifar100_accuracy: 0.1900 - c2_predictions_cifar100_loss: 2.5829 - loss: 0.1237 - predictions_cifar100_accuracy: 0.0671 - predictions_cifar100_loss: 3.7144 - val_c1_predictions_cifar100_accuracy: 0.9902 - val_c1_predictions_cifar100_loss: 0.0379 - val_c2_predictions_cifar100_accuracy: 0.3799 - val_c2_predictions_cifar100_loss: 2.0239 - val_loss: 0.0903 - val_predictions_cifar100_accuracy: 0.0959 - val_predictions_cifar100_loss: 3.3144 - learning_rate: 0.0010
# Epoch 10/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1487s 9s/step - c1_predictions_cifar100_accuracy: 0.9870 - c1_predictions_cifar100_loss: 0.0565 - c2_predictions_cifar100_accuracy: 0.2038 - c2_predictions_cifar100_loss: 2.5353 - loss: 0.1176 - predictions_cifar100_accuracy: 0.0773 - predictions_cifar100_loss: 3.6843 - val_c1_predictions_cifar100_accuracy: 0.9902 - val_c1_predictions_cifar100_loss: 0.0377 - val_c2_predictions_cifar100_accuracy: 0.3457 - val_c2_predictions_cifar100_loss: 2.0379 - val_loss: 0.0894 - val_predictions_cifar100_accuracy: 0.1190 - val_predictions_cifar100_loss: 3.2466 - learning_rate: 0.0010
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step
# --- BA-CNN Base C ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9921360015869141
# Accuracy level 2: 0.3375132977962494
# Accuracy level 3: 0.11370882391929626
# --- Hierarchical Metrics ---
# Accuracy: 0.05334750265674814
# Consistency: 0.2059511158342189
# f1: 0.4856839121190645
# Parameters: 15,286,871
